# %% [markdown]
# <a href="https://colab.research.google.com/github/VarunMishra1998/Python-/blob/main/numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install numpy

# %%
import numpy as np

# %%
ar_zero = np.zeros(4)
print (ar_zero)
# Out:
# [0. 0. 0. 0.]
